# %% [markdown]
# # Lab

# %% [markdown]
# ## Intro to Numeric Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data

# %%
x = np.array([3, 4, 5])
y = np.array([4, 9, 7])

# %%
x + y
# Out:
# array([ 7, 13, 12])

# %%
x = np.array([
    [1, 2],
    [3, 4]
])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# ### sample of array attributes

# %%
x.ndim
# Out:
# 2

# %%
x.dtype
# Out:
# dtype('int64')

# %%
x.shape
# Out:
# (2, 2)

# %% [markdown]
# ### Reshape array

# %%
x = np.array([1, 2, 3, 4, 5, 6])
print(f'beginning x:\n {x}')
x_reshape = x.reshape((2, 3))
print(f'reshaped x:\n {x_reshape}')
# Out:
# beginning x:
#  [1 2 3 4 5 6]
# reshaped x:
#  [[1 2 3]
#  [4 5 6]]

# %%
print(f'x before any modification:\n {x}')
print()

print(f'x before any reshaping:\n {x_reshape}')
print()

x_reshape[0, 0] = 10
print(f'x_reshape after modifying its top left element:\n {x_reshape}')
print()

print(f'x after modifying x_reshape top left element:\n {x}')
# Out:
# x before any modification:
#  [1 2 3 4 5 6]
#
# x before any reshaping:
#  [[1 2 3]
#  [4 5 6]]
#
# x_reshape after modifying its top left element:
#  [[10  2  3]
#  [ 4  5  6]]
#
# x after modifying x_reshape top left element:
#  [10  2  3  4  5  6]

# %% [markdown]
# ## Math operations on array

# %%
np.sqrt(x)
# Out:
# array([3.16227766, 1.41421356, 1.73205081, 2.        , 2.23606798,
#        2.44948974])

# %%
x**2
# Out:
# array([100,   4,   9,  16,  25,  36])

# %%
x**0.5
# Out:
# array([3.16227766, 1.41421356, 1.73205081, 2.        , 2.23606798,
#        2.44948974])

# %% [markdown]
# ## Generate random data

# %%
x = np.random.normal(size=50)
x
# Out:
# array([ 0.16316748, -0.71155001, -0.15632338, -0.33760445, -0.61685844,
#         0.30693621,  0.28869032, -0.90298249, -0.85700176,  1.81660409,
#        -0.39218709, -0.16672337, -1.91599282,  0.69845406,  0.48493793,
#         0.18197068,  1.32380312, -0.83976294, -1.28280499, -0.71652389,
#        -1.90042087,  0.11252607,  2.24987395, -0.33540191, -2.25827508,
#         0.48706224, -0.01838485,  0.69384719, -0.2937229 , -0.14624753,
#        -0.12554095,  0.71096604, -0.11929454,  0.25885121,  0.11083514,
#         0.86895657,  0.12725958,  1.11684576, -0.34793128,  0.69740917,
#        -0.32905305, -0.97744185, -0.14785063, -1.11614971, -1.16704929,
#         0.63175499, -1.6923453 ,  1.12292382, -0.82351848, -0.73888856])

# %%
y = x + np.random.normal(50, 1, 50)
y
# Out:
# array([51.18241082, 50.68520632, 52.03599995, 49.74937152, 48.53732588,
#        50.42525384, 49.18140304, 50.11926723, 49.55632248, 51.928312  ,
#        50.60231725, 49.16787298, 48.08863715, 50.5220738 , 50.33256145,
#        51.00766891, 51.43065043, 49.45450629, 45.84727369, 49.18870781,
#        49.57602453, 50.34685258, 52.11786191, 49.60787704, 48.9969348 ,
#        50.92615964, 49.86786364, 50.54151362, 49.2737951 , 49.68966499,
#        49.69193143, 50.24748104, 48.98429869, 51.75707326, 51.83409971,
#        51.37817367, 50.05554095, 51.81011472, 49.51409774, 51.8248235 ,
#        50.37018609, 48.87453542, 51.1247929 , 48.91354   , 46.07129672,
#        49.90106835, 48.04474706, 50.34051391, 49.73777864, 47.94212658])

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.69929365],
#        [0.69929365, 1.        ]])

# %% [markdown]
# ## Graphics

# %%
from matplotlib.pyplot import subplots

# %%
rng = np.random.default_rng(1303)
fix, ax = subplots(figsize=(8, 8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.plot(x, y)

# %% [markdown]
# ## Code exercise

# %% [markdown]
# ### 8a)

# %%
path = r'./College.csv'
college = pd.read_csv(path)
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ### 8b)

# %%
college2 = pd.read_csv(path, index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index('College')

# %%
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college = college3

# %% [markdown]
# ### 8c)

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### 8d)

# %%
scatter_cols= ['Top10perc', 'Apps', 'Enroll']
pd.plotting.scatter_matrix(college[scatter_cols], alpha=0.2)
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# ### 8e)

# %%
ax = college.boxplot(column='Outstate', by='Private')
plt.suptitle('')
ax.set_title('Out-of-state tuition among public and state institutions')
plt.show()

# %% [markdown]
# ### 8f)

# %%
top_ten_perc = college['Top10perc']
threshold = [0, 50, 100]
labels = ['no', 'yes']
college['elite'] = pd.cut(top_ten_perc, bins=threshold, labels=labels)

# %%
college['elite'].value_counts()
# Out:
# elite
# no     699
# yes     78
# Name: count, dtype: int64

# %%
ax = college.boxplot(column='Outstate', by='elite')
plt.suptitle('')
ax.set_title('Out-of-state tuition among perceived elite and non-elite institutions')
plt.show()

# %% [markdown]
# ### 8g)

# %%
college['Grad.Rate'] = college['Grad.Rate'].clip(upper=100)
ax = college.plot.hist(column=['Grad.Rate'], by="Private", figsize=(10, 8))
plt.suptitle('Graduation rate grouped by public vs private institutions')
plt.tight_layout()

# %% [markdown]
# ### 8h)

# %%
ax = college.boxplot(column='perc.alumni', by='Private')
plt.suptitle('')
ax.set_title('% of alumni who donate among public and state institutions')
plt.show()

# %%
ax = college.boxplot(column='S.F.Ratio', by='Private')
plt.suptitle('')
ax.set_title('Student/faculty ratio among public and state institutions')
plt.show()

# %% [markdown]
# ### 9a)

# %%
auto_data_path = r'Auto.csv'
auto = pd.read_csv(auto_data_path)
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %% [markdown]
# *Quantitative predictors*: origin \
# *Qualitative predictors*: miles per gallon, Number of cylinders, Engine displacement, Engine horsepower, weight, Time to accelerate, year

# %% [markdown]
# ### 9b)

# %%
quantitative_predictors = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']
pd_quantitative = auto[quantitative_predictors]

# %%
np.min(pd_quantitative, axis=0)
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# dtype: float64

# %%
np.max(pd_quantitative, axis=0)
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          5140.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %% [markdown]
# ### 9c)

# %%
np.mean(pd_quantitative, axis=0)
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64

# %%
np.std(pd_quantitative, axis=0)
# Out:
# mpg               7.795046
# cylinders         1.703606
# displacement    104.510444
# horsepower       38.442033
# weight          848.318447
# acceleration      2.755343
# year              3.679035
# dtype: float64

# %% [markdown]
# ### 9d)

# %%
auto_reduced = auto.drop(auto.index[10:86])

# %%
auto_reduced.describe()
# Out:
#               mpg   cylinders  displacement  horsepower      weight  \
# count  316.000000  316.000000    316.000000  316.000000   316.00000
# mean    24.407595    5.373418    187.512658  100.848101  2936.53481
# std      7.863285    1.654179    100.114616   35.954147   811.87445
# min     11.000000    3.000000     68.000000   46.000000  1649.00000
# 25%     18.000000    4.000000    100.250000   75.000000  2213.75000
# 50%     23.950000    4.000000    145.500000   90.000000  2792.50000
# 75%     30.550000    6.000000    250.000000  115.000000  3508.00000
# max     46.600000    8.000000    455.000000  230.000000  4997.00000
#
#        acceleration        year      origin
# count    316.000000  316.000000  316.000000
# mean      15.717405   77.136076    1.601266
# std        2.713876    3.123464    0.819910
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %% [markdown]
# ### 9e)

# %%
ax = auto.boxplot(column='weight', by='origin')
plt.suptitle('')
ax.set_title('Car weight based on origin')
plt.show()

# %%
ax = auto.boxplot(column='horsepower', by='origin')
plt.suptitle('')
ax.set_title('Engine horsepower based on origin')
plt.show()

# %% [markdown]
# *Findings*: American manufactured cars are a lot heavier on averge and have far more engine hoursepower than Europe and Japanese made cars

# %% [markdown]
# ### 9f)

# %%
scatter_cols= ['mpg', 'weight', 'acceleration', 'displacement', 'horsepower']
pd.plotting.scatter_matrix(auto[scatter_cols], alpha=0.2, figsize = (12, 12))
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='weight'>,
#         <Axes: xlabel='weight', ylabel='weight'>,
#         <Axes: xlabel='acceleration', ylabel='weight'>,
#         <Axes: xlabel='displacement', ylabel='weight'>,
#         <Axes: xlabel='horsepower', ylabel='weight'>],
#        [<Axes: xlabel='mpg', ylabel='acceleration'>,
#         <Axes: xlabel='weight', ylabel='acceleration'>,
#         <Axes: xlabel='acceleration', ylabel='acceleration'>,
#         <Axes: xlabel='displacement', ylabel='acceleration'>,
#         <Axes: xlabel='horsepower', ylabel='acceleration'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>,
# ...

# %% [markdown]
# *findings*: base don data viz, 'weight','displacement', 'horsepower' might be helpful predicting miles per hour \
# weight, hoursepower, engine displacement all inversed affect miles per gallon;

# %% [markdown]
# ### 10a)

# %%
boston = load_data('Boston')

# %% [markdown]
# ### 10b)

# %%
boston.shape
# Out:
# (506, 13)

# %% [markdown]
# There are 506 rows and 13 columns in the dataset. 506 rows means there are 506 observations. 13 columns means each observation has 13 attributes

# %% [markdown]
# ###  10c)

# %%
pd.plotting.scatter_matrix(boston, alpha=0.2, figsize = (22, 22))
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
#         <Axes: xlabel='chas', ylabel='crim'>,
#         <Axes: xlabel='nox', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='ptratio', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='zn'>,
#         <Axes: xlabel='zn', ylabel='zn'>,
#         <Axes: xlabel='indus', ylabel='zn'>,
#         <Axes: xlabel='chas', ylabel='zn'>,
#         <Axes: xlabel='nox', ylabel='zn'>,
#         <Axes: xlabel='rm', ylabel='zn'>,
#         <Axes: xlabel='age', ylabel='zn'>,
#         <Axes: xlabel='dis', ylabel='zn'>,
# ...

# %% [markdown]
# ### 10d)
# median home value have particularly pronounced effect on crime rate

# %% [markdown]
# ### 10e)

# %%
quantitative_predictors = ['crim', 'tax', 'ptratio']
boston[quantitative_predictors].describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# There are huge variance in crime rate while the top 75% of suburbs has a per-capita crime rate of less than 4, one suburb has a outlier of 88 per-capita crime rate\
# The property tax and pupil-teacher ratio appear be to be in normal distribution

# %% [markdown]
# ### 10f)

# %%
boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# 35 suburbs are Charles river bound; 471 suburbs are not

# %% [markdown]
# ### 10g)

# %%
np.median(boston['ptratio'])
# Out:
# 19.05

# %% [markdown]
# The median pupil-teacher ratio is 19.05

# %% [markdown]
# ### 10h)

# %%
home_value_min = np.min(boston['medv'])
lowest_home_value_suburbs = boston[boston['medv'] == home_value_min] 
lowest_home_value_suburbs
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %% [markdown]
# There are two suburbs with the lowest median home value of 5.0 and the per capita crime rate is 10 to 20 times of avearge crime rate

# %% [markdown]
# ### 10i)

# %%
boston[boston['rm'] > 7].shape[0]
# Out:
# 64

# %%
boston[boston['rm'] > 8].shape[0]
# Out:
# 13

# %% [markdown]
# There are 64 suburbs average more than seven room per dwelling and 13 suburbs average more than eight room per dwelling
