# %% [markdown]
# # Lab

# %% [markdown]
# ## Intro to Numeric Python

# %%
import numpy as np

# %%
x = np.array([3, 4, 5])
y = np.array([4, 9, 7])

# %%
x + y
# Out:
# array([ 7, 13, 12])

# %%
x = np.array([
    [1, 2],
    [3, 4]
])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# ### sample of array attributes

# %%
x.ndim
# Out:
# 2

# %%
x.dtype
# Out:
# dtype('int64')

# %%
x.shape
# Out:
# (2, 2)

# %% [markdown]
# ### Reshape array

# %%
x = np.array([1, 2, 3, 4, 5, 6])
print(f'beginning x:\n {x}')
x_reshape = x.reshape((2, 3))
print(f'reshaped x:\n {x_reshape}')
# Out:
# beginning x:
#  [1 2 3 4 5 6]
# reshaped x:
#  [[1 2 3]
#  [4 5 6]]
