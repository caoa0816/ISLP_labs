# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Excercise 8.

# %% [markdown]
# #### 8a)

# %%
college=pd.read_csv("College.csv")

# %% [markdown]
# #### 8b)

# %%
college2=pd.read_csv("College.csv", index_col=0)
college3=college.rename({"Unnamed: 0": "College"}, axis=1)
college3=college3.set_index("College")
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college = college3
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# #### 8c)

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# #### 8d)

# %%
selected_c=pd.DataFrame(college, columns=["Top10perc", "Apps", "Enroll"])
pd.plotting.scatter_matrix(selected_c)
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# #### 8e)

# %%
sns.boxplot(x=college['Private'], y=college['Outstate'])
# Out:
# <Axes: xlabel='Private', ylabel='Outstate'>

# %% [markdown]
# #### 8f)

# %%
college['Elite'] = college['Top10perc'].apply(lambda x: "Yes" if x > 50 else "No")

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
(college["Top10perc"]>50).sum()
# Out:
# 78

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
sns.boxplot(x=college['Elite'], y=college['Outstate'])
# Out:
# <Axes: xlabel='Elite', ylabel='Outstate'>

# %% [markdown]
# #### 8g)

# %%
college["Apps"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
hist_1 = pd.DataFrame(college, columns=["Top10perc"])
hist_1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Excercise 9

# %%
auto=pd.read_csv('/home/acao/ISLP_labs/Auto.csv')
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# #### 9a)

# %% [raw]
# Qualitative predictors: mpg, cylinders, displacement, horsepower, weight, acceleration
# quantitative predictors: origin, year

# %% [markdown]
# ### 9b) & 9c)

# %%
numerical_measure = auto[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration']]

# %%
numerical_measure_stats = numerical_measure.describe()

# %%
numerical_measure_stats.loc[['min','max','mean','std']]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min    9.000000   3.000000     68.000000   46.000000  1613.000000
# max   46.600000   8.000000    455.000000  230.000000  5140.000000
# mean  23.445918   5.471939    194.411990  104.469388  2977.584184
# std    7.805007   1.705783    104.644004   38.491160   849.402560
#
#       acceleration
# min       8.000000
# max      24.800000
# mean     15.541327
# std       2.758864

# %% [markdown]
# ### 9d)

# %%
auto_reduced_data = auto.drop(index=range(9, 85))
auto_reduced_data_numerical = auto_reduced_data[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration']]

# %%
auto_reduced_data_numerical.describe().loc[['min','max','mean','std']]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min   11.000000   3.000000     68.000000   46.000000  1649.000000
# max   46.600000   8.000000    455.000000  230.000000  4997.000000
# mean  24.404430   5.373418    187.240506  100.721519  2935.971519
# std    7.867283   1.654179     99.678367   35.708853   811.300208
#
#       acceleration
# min       8.500000
# max      24.800000
# mean     15.726899
# std       2.693721

# %% [markdown]
# #### 9e)

# %%
# investigate relationship between miles per gallon & weight

# %%
auto.plot(kind="scatter", x="weight", y="mpg", title="Relationship btw weight and mpg")
# Out:
# <Axes: title={'center': 'Relationship btw weight and mpg'}, xlabel='weight', ylabel='mpg'>

# %% [markdown]
# ### Excercise 10

# %% [markdown]
# #### 10a)

# %%
from ISLP import load_data
boston = load_data('Boston')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# #### 10b)

# %%
boston.shape
# Out:
# (506, 13)

# %% [raw]
# there are 506 rows & 13 columns in the dataset; 506 rows means there are 506 observations made; 13 columns means there are 13 variables;

# %% [markdown]
# #### 10c)

# %%
boston.plot(kind="scatter", x="medv", y="crim", title="Relationship btw home value and crime rate")
# Out:
# <Axes: title={'center': 'Relationship btw home value and crime rate'}, xlabel='medv', ylabel='crim'>

# %%
boston.plot(kind="scatter", x="rm", y="medv", title="Relationship btw room & home value")
# Out:
# <Axes: title={'center': 'Relationship btw room & home value'}, xlabel='rm', ylabel='medv'>

# %%
boston.plot(kind="scatter", x="dis", y="medv", title="Relationship btw distance to job centers & home value")
# Out:
# <Axes: title={'center': 'Relationship btw distance to job centers & home value'}, xlabel='dis', ylabel='medv'>

# %%
boston.plot(kind="scatter", x="tax", y="ptratio", title="Relationship between property tax & pupil-teacher ratio")
# Out:
# <Axes: title={'center': 'Relationship between property tax & pupil-teacher ratio'}, xlabel='tax', ylabel='ptratio'>

# %%
boston.plot(kind="scatter", x="lstat", y="crim",  title="Relationship between % of lower status population & crime rate")
# Out:
# <Axes: title={'center': 'Relationship between % of lower status population & crime rate'}, xlabel='lstat', ylabel='crim'>

# %% [markdown]
# #### 10d)

# %% [raw]
# There appeared to be correlations between % of lower status population, distances to five Boston employment centres, median value of owner-occupied homes  & crime

# %%
boston.plot(kind="scatter", x="dis", y="crim", title="Relationship between distances to five Boston employment centres & crime")
# Out:
# <Axes: title={'center': 'Relationship between distances to five Boston employment centres & crime'}, xlabel='dis', ylabel='crim'>

# %%
boston.plot(kind="scatter", x="medv", y="crim")
# Out:
# <Axes: xlabel='medv', ylabel='crim'>

# %%
boston.plot(kind="scatter", x="rad", y="crim")
# Out:
# <Axes: xlabel='rad', ylabel='crim'>
