# %% [markdown]
# <h2>Numerical python, such as numpy package, etc</h2>

# %%
import numpy as np

# %%
x = np.array([4, 9, 2])
y = np.array([3, 1, 7])

# %%
x + y
# Out:
# array([ 7, 10,  9])

# %% [markdown]
# <h3>Two dimensional array, aka matrices, example below</h3>

# %%
a = np.array([[2, 4, 1], [5, 9, 7]])
a
# Out:
# array([[2, 4, 1],
#        [5, 9, 7]])

# %% [markdown]
# <h3>One dimensional array, aka ventor, example below <h3>

# %%
b = np.array([7, 9])
b
# Out:
# array([7, 9])

# %% [markdown]
# <h3>array attribute</h3>

# %%
print(a.flags)
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False

# %%
print(a.shape)
# Out:
# (2, 3)

# %%
print(a.strides)
# Out:
# (24, 8)

# %%
print(a.ndim)
# Out:
# 2

# %%
print(a.size)
# Out:
# 6

# %%
print(a.dtype)
# Out:
# int64
