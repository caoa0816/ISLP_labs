# %% [markdown]
# # Conceptual

# %% [raw]
# 1a) large observation, small predictors: inflexible statistical learning method might be better.
# b/c inflexible statistical learning method will able to capture the relationship between the predictors and the responses.
#
# 1b) large predictors and small observations: flexible statistical learning method might be better
# b/c it will capture the various relationship between predictors and responses
#
# 1c) non-linear relationship between predictors and responses: flexible
#
# 1d) high error terms: depends wether or not the error terms are due to high variance or bias.

# %% [raw]
# 2a)
# regression problem because the response is quantitative;
# this is an inference problem;
# n = 500; p = headout, industry, profit
#
# 2b)
# classification problem because ther esponse is qualitative;
# this is a prediction problem;
# n = 20; p = price, marketing budget, competition price .... 10 more
#
# 2c)
# regression problem because the response is qualitative;
# This is a inference problem;
# n = number of weeks in 2012; p = % change in the US market, % change in the British market & % change in the German market

# %% [raw]
# 4a)
# response: document type; predictor: document texts; prediction problem
# response: Covid postive/negative outcome; predictor: medical history; prediction problem
# response: wether or not a customer will open a new credit card based on marketing outreach; predictor: marketing budget, social media spending, snail mail spending, tv/radio spending
#
# 4b)
# response: future earnings; predictor: advanced degree, occupation; prediction problem
# response: future population growth; predictor: $$ invested in education
#
# 4c)
# customer segmantation

# %% [markdown]
# # Applied

# %% [markdown]
# ## 8. College data

# %%
from ISLP import load_data

# %%
college = load_data('College')
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='object')

# %%
college.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college = college.rename({"Unmaned: 0": "College"}, axis=1)
college.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...
