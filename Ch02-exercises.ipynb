# %% [markdown]
# # Conceptual

# %% [markdown]
# ## 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# (a) The sample size n is extremely large, and the number of predictors p is small. <br>
# Flexible method >> flexible methods often required large sample size for better estimation.

# %% [markdown]
# (b) The number of predictors p is extremely large, and the number
# of observations n is small. <br>
# Inflexible methods >> when n is small and p is large, the data is more suitable for inference problems than prediction problems

# %% [markdown]
# (c) The relationship between the predictors and response is highly
# non-linear. <br>
# Flexible methods >> when the relationship between the predictors and response is highly non-linear, it's hard to draw any conclusion about the correlation between predictor & response. As a result, inflexible approach might not be ideal

# %% [markdown]
# (d) The variance of the error terms, i.e. σ2 = Var("), is extremely
# high. <br>
# Flexible methods >> When the variance of the error terms is high, inflexible methods such as linear regression performances will not be able to capture the true form of f. Flexibe methods will be better approach to reduce the error

# %% [markdown]
# ## 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.

# %% [markdown]
# (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
# <br>
# Regression problem because CEO salary is a quantitative response.<br>
# n = 500 <br>
# p = profit, employee headcount, industry

# %% [markdown]
# (b) We are considering launching a new product and wish to know
# whether it will be a success or a failure. We collect data on 20
# similar products that were previously launched. For each product we have recorded whether it was a success or failure, price
# charged for the product, marketing budget, competition price,
# and ten other variables <br>
# <br>
# Classification problem because the response will be binary <br>
# n = 20 <br>
# p = price, marketing budget, competition price

# %% [markdown]
# (c) We are interested in predicting the % change in the USD/Euro
# exchange rate in relation to the weekly changes in the world
# stock markets. Hence we collect weekly data for all of 2012. For
# each week we record the % change in the USD/Euro, the %
# change in the US market, the % change in the British market,
# and the % change in the German market. <br>
#
# Regression problem <br>
# n = # of weeks in a year<br>
# p = % change in the USD/Euro, the %
# change in the US market, the % change in the British market,
# and the % change in the German market.<br>

# %% [markdown]
# # 3. We now revisit the bias-variance decomposition.
# (a) Describe (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot<br>
# (b) Explain why each of the five curves has the shape displayed in part (a).

# %% [markdown]
# <pre>
# Variance: amount by which estimated f would change if we estimate using a different training dataset
#     High Varaince: small change in traning data will result in large change in estimation
#     Flexible approaches will have higher variance
#
# Bias: error introduced by approximating real-life problem
#     More flexible approaches will have lower bias
#     ex: Linear regression is making assumptiosn about the param & output -> might need to more bias
# </pre>

# %% [markdown]
# <pre>
# Squared bias:
#     decrease rapdily in the beginning then remain flat
# variance:
#     increase at different rate. Inverse relationship with squared bias.
# Training error:
#     as flexibility increases, error rate will decrease as the model will ty to fit into the training data.
# Testing error:
#     as flexibility increases, error rate might increase as the model might overfit the training data and do a poor job predict data the model has never seen before
# Irreducible error:
#     horizontal line. The error is fixed regardless of degree of flexibility or change of training dataset.
# </pre>

# %% [markdown]
# ## 4. You will now think of some real-life applications for statistical learning.

# %% [markdown]
# (a) Describe three real-life applications in which classification might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.<br>
#
# Application: classifying document types, such as invoice, credit note etc<br>
# input: OCR'd document files

# %% [markdown]
# (b) Describe three real-life applications in which regression might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.<br>
#
# Application: forecast sales<br>
# Input: spending, customer demographics etc

# %% [markdown]
# (c) Describe three real-life applications in which cluster analysis
# might be useful<br>
# Application: customer segmentation<br>
# Input: customer zip code, income, occupation, gender, age etc

# %% [markdown]
# ## 5. What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?

# %% [markdown]
# If the main focus is inference, then inflexible approach might be preferred and inflexible/restrictive models are easy to interprete. If the focus is prediction, then a more flexible approach will be preferered

# %% [markdown]
# # 6. Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a nonparametric approach)? What are its disadvantages?

# %% [markdown]
# Parametric approaches reduce the estimation problem to the estimation of few parameters by making assumptions about the parameters that will impact the final estimaton. <br>
# Parametric approaches advantage: easy implemention & only needs small number of dataset<br>
# Parametric approaches disadvantage: estimation might not reflect the true form of function<br>
# <br>
# Non-parametric approach doesn't make any assumptions about the form of the function f, so the estimation will be more accurate<br>
# Non-parametric approach disadvantage: more data needed & overfitting of training data

# %% [markdown]
# # 7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.

# %% [markdown]
# Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors. <br>
# (a) Compute the Euclidean distance between each observation and
# the test point, X1 = X2 = X3 = 0. <br>
# (b) What is our prediction with K = 1? Why? <br>
# (c) What is our prediction with K = 3? Why? <br>
# (d) If the Bayes decision boundary in this problem is highly nonlinear, then would we expect the best value for K to be large or
# small? Why?

# %%
import math

# %%
print("Part a answer:")
print(f"Observation 1 Euclidean distance: {math.sqrt(9)}")
print(f"Observation 2 Euclidean distance: {math.sqrt(4)}")
print(f"Observation 3 Euclidean distance: {math.sqrt(10)}")
print(f"Observation 4 Euclidean distance: {math.sqrt(5)}")
print(f"Observation 5 Euclidean distance: {math.sqrt(2)}")
print(f"Observation 6 Euclidean distance: {math.sqrt(3)}")
# Out:
# Part a answer:
# Observation 1 Euclidean distance: 3.0
# Observation 2 Euclidean distance: 2.0
# Observation 3 Euclidean distance: 3.1622776601683795
# Observation 4 Euclidean distance: 2.23606797749979
# Observation 5 Euclidean distance: 1.4142135623730951
# Observation 6 Euclidean distance: 1.7320508075688772

# %% [markdown]
# (b) When K=1, the closest observation is number 5. Prediction is Green.

# %% [markdown]
# (c) when K=3, cloest observations are 2, 5, 6. 2 out of the 3 observations are red, so the prediciton is red

# %% [markdown]
# (d) When the decision boundry is nonlinear, we might want a flexible approach and a small K value might be more appropriate

# %% [markdown]
# # Applied

# %% [markdown]
# ## 8. This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US.

# %%
import pandas as pd

# %%
# (a) Use the pd.read_csv() function to read the data into Python. Call the loaded data college.
college = pd.read_csv("College.csv")
college.head(5)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %% [markdown]
# (b) Look at the data used in the notebook by creating and running
# a new cell with just the code college in it. You should notice
# that the first column is just the name of each university in a
# column named something like Unnamed: 0. We don’t really want
# pandas to treat this as data. However, it may be handy to have
# these names for later. Try the following commands and similarly
# look at the resulting data frames:

# %%
college2 = pd.read_csv('College.csv', index_col=0)
college2.head(5)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# Abilene Christian University        3300    450      2200   70        78
# Adelphi University                  6450    750      1500   29        30
# Adrian College                      3750    400      1165   53        66
# Agnes Scott College                 5450    450       875   92        97
# Alaska Pacific University           4120    800      1500   76        72
#
#                               S.F.Ratio  perc.alumni  Expend  Grad.Rate
# Abilene Christian University       18.1           12    7041         60
# Adelphi University                 12.2           16   10527         56
# Adrian College                     12.9           30    8735         54
# Agnes Scott College                 7.7           37   19016         59
# Alaska Pacific University          11.9            2   10922         15

# %%
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3.head(5)
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %%
college3 = college3.set_index('College')
college3.head(5)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# College
# Abilene Christian University        3300    450      2200   70        78
# Adelphi University                  6450    750      1500   29        30
# Adrian College                      3750    400      1165   53        66
# Agnes Scott College                 5450    450       875   92        97
# Alaska Pacific University           4120    800      1500   76        72
#
#                               S.F.Ratio  perc.alumni  Expend  Grad.Rate
# College
# Abilene Christian University       18.1           12    7041         60
# Adelphi University                 12.2           16   10527         56
# Adrian College                     12.9           30    8735         54
# Agnes Scott College                 7.7           37   19016         59
# Alaska Pacific University          11.9            2   10922         15

# %%
# (c) Use the describe() method of to produce a numerical summary of the variables in the data set.
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %% [markdown]
# (d) Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the first columns [Top10perc, Apps, Enroll].

# %%
cols = ["Top10perc", "Apps", "Enroll"]
top_10_perc_enrollment = college.loc[:,cols]
pd.plotting.scatter_matrix(top_10_perc_enrollment)
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
# (e) Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private.
college.boxplot(column=['Outstate'], by=['Private'])
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='[Private]'>

# %%
# (f) Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups 
# based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
college['Elite'] = pd.cut(college['Top10perc'],[0,50,100],labels=['No', 'Yes'])
college.head(5)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate Elite
# 0   70        78       18.1           12    7041         60    No
# 1   29        30       12.2           16   10527         56    No
# 2   53        66       12.9           30    8735         54    No
# 3   92        97        7.7           37   19016         59   Yes
# 4   76        72       11.9            2   10922         15    No

# %%
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot(column=['Outstate'], by=['Elite'])
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='[Elite]'>

# %%
# (g) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. 

# quantitative variables: Instructional expenditure per student 
college.plot.hist(column=["Expend"], by="Private", bins=15)
# Out:
# array([<Axes: title={'center': 'No'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'Yes'}, ylabel='Frequency'>], dtype=object)

# %%
#  Continue exploring the data, and provide a brief summary of what you discover.
# Room and board costs between private & public colleges
college.boxplot(column=['Room.Board'], by=['Elite'])
# Out:
# <Axes: title={'center': 'Room.Board'}, xlabel='[Elite]'>

# %% [markdown]
# ## 9. This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
auto = pd.read_csv("Auto.csv")
auto.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### step 1: understand data

# %%
auto.shape
# Out:
# (392, 9)

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
cols = auto.columns.values.tolist()

# %% [markdown]
# ### Step 2: Check Missing Values

# %%
for col in cols:
    print(f"{col} missing value count: {auto["mpg"].isnull().sum()}")
# Out:
# mpg missing value count: 0
# cylinders missing value count: 0
# displacement missing value count: 0
# horsepower missing value count: 0
# weight missing value count: 0
# acceleration missing value count: 0
# year missing value count: 0
# origin missing value count: 0
# name missing value count: 0

# %%
auto.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### excercises

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?
# <pre>
# Quantitative predictors:
#     mpg, cylinders, displacement, weight, acceleration
# Qualitative predictors:
#     year, origin
# </pre>

# %%
# (b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy. 
# (c) What is the mean and standard deviation of each quantitative predictor?
quantitative_predicctors = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration"]

# %%
import numpy as np

# %%
for predictor in quantitative_predicctors:
    min_value = np.min(auto[predictor])
    max_value = np.max(auto[predictor])
    mean = np.mean(auto[predictor])
    s_deviation = np.std(auto[predictor])
    print(f"{predictor} range: from {min_value} to {max_value}")
    print(f"{predictor} mean: {mean:.2f}")
    print(f"{predictor} standard deviation: {s_deviation:.2f}")
    print()
# Out:
# mpg range: from 9.0 to 46.6
# mpg mean: 23.45
# mpg standard deviation: 7.80
#
# cylinders range: from 3 to 8
# cylinders mean: 5.47
# cylinders standard deviation: 1.70
#
# displacement range: from 68.0 to 455.0
# displacement mean: 194.41
# displacement standard deviation: 104.51
#
# horsepower range: from 46 to 230
# horsepower mean: 104.47
# horsepower standard deviation: 38.44
#
# weight range: from 1613 to 5140
# weight mean: 2977.58
# weight standard deviation: 848.32
#
# acceleration range: from 8.0 to 24.8
# acceleration mean: 15.54
# acceleration standard deviation: 2.76

# %%
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?
auto_reduced = auto.drop(auto.index[10:86])
auto_reduced.shape
# Out:
# (316, 9)

# %%
for predictor in quantitative_predicctors:
    min_value = np.min(auto_reduced[predictor])
    max_value = np.max(auto_reduced[predictor])
    mean = np.mean(auto_reduced[predictor])
    s_deviation = np.std(auto_reduced[predictor])
    print(f"{predictor} range: from {min_value} to {max_value}")
    print(f"{predictor} mean: {mean:.2f}")
    print(f"{predictor} standard deviation: {s_deviation:.2f}")
    print()
# Out:
# mpg range: from 11.0 to 46.6
# mpg mean: 24.41
# mpg standard deviation: 7.85
#
# cylinders range: from 3 to 8
# cylinders mean: 5.37
# cylinders standard deviation: 1.65
#
# displacement range: from 68.0 to 455.0
# displacement mean: 187.51
# displacement standard deviation: 99.96
#
# horsepower range: from 46 to 230
# horsepower mean: 100.85
# horsepower standard deviation: 35.90
#
# weight range: from 1649 to 4997
# weight mean: 2936.53
# weight standard deviation: 810.59
#
# acceleration range: from 8.5 to 24.8
# acceleration mean: 15.72
# acceleration standard deviation: 2.71

# %%
"""
(e) Using the full data set, investigate the predictors graphically, 
using scatterplots or other tools of your choice. Create some plots
highlighting the relationships among the predictors. Comment on your findings.
"""

"""
    I am investigating the percentile and weight and acceleration and trying to uncover the car design trends 
"""
auto.boxplot(column=['weight'])
# Out:
# <Axes: >

# %%
auto.boxplot(column=['acceleration'])
# Out:
# <Axes: >

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.

# %% [markdown]
# I will make assumption about year, weight & acceleration are correlated to mpg, either individually or in aggregate, as <br>
# car make year might influence type of technology in the car, thus affect the mileage. As weight and acceleration.

# %% [markdown]
# ### 10. This exercise involves the Boston housing data set.

# %% [markdown]
# #### (a) To begin, load in the Boston data set, which is part of the ISLP library.

# %%
from ISLP import load_data
boston = load_data('Boston')
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
boston.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# lstat      float64
# medv       float64
# dtype: object

# %% [markdown]
# #### (b)How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
"""
There are 506 rows & 13 columns in this data set. The rows represent data size n and columns represent the attributes of the data set
"""
boston.shape
# Out:
# (506, 13)

# %% [markdown]
# #### (c) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
"""
scatter platter of per capita crime rate & proportion of non-retail business acres per town
"""
crim_indus = boston.loc[:, ["crim", "indus"]]
crim_indus.plot.scatter(x='crim', y='indus',  c='blue')
# Out:
# <Axes: xlabel='crim', ylabel='indus'>

# %%
"""
scatter platter of per capita crime rate & median home value.

Lower the crime rate, higher the home value, but there are still some outliers where towns with lower crime rate still has low home value
"""
crim_medv = boston.loc[:, ["crim", "medv"]]
crim_medv.plot.scatter(x='crim', y='medv', c='blue')
# Out:
# <Axes: xlabel='crim', ylabel='medv'>

# %% [markdown]
# #### (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
dis_crim = boston.loc[:, ["dis", "crim"]]
dis_crim.plot.scatter(x='dis', y='crim', c='blue')
# Out:
# <Axes: xlabel='dis', ylabel='crim'>

# %%
lstat_crim = boston.loc[:, ["lstat", "crim"]]
lstat_crim.plot.scatter(x="lstat", y="crim", c='blue')
# Out:
# <Axes: xlabel='lstat', ylabel='crim'>

# %% [markdown]
# There appears to be some correlation between distances to five Boston employment centres & crime rate.<br>
# The closer the town is to the metro area, the higher the crime rate

# %% [markdown]
# #### (e) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
boston['crim'].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crim, dtype: float64

# %%
boston['high_crime_area'] = pd.cut(boston['crim'],[0,3.677083,89],labels=['no','yes'])
high_crime = boston[boston['high_crime_area']=='yes']

# %%
high_crime.describe()
# Out:
#              crim     zn       indus        chas         nox          rm  \
# count  127.000000  127.0  127.000000  127.000000  127.000000  127.000000
# mean    13.143674    0.0   18.111654    0.055118    0.677000    5.995835
# std     13.148669    0.0    0.131329    0.229114    0.061571    0.689004
# min      3.678220    0.0   18.100000    0.000000    0.532000    3.561000
# 25%      5.822580    0.0   18.100000    0.000000    0.631000    5.665500
# 50%      9.329090    0.0   18.100000    0.000000    0.693000    6.167000
# 75%     14.377250    0.0   18.100000    0.000000    0.713000    6.414000
# max     88.976200    0.0   19.580000    1.000000    0.871000    7.393000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000  127.000000
# mean    91.449606    1.998548   23.850394  663.929134   20.156693   19.004567
# std      9.945493    0.546017    1.685977   23.337476    0.488046    6.850350
# min     53.200000    1.129600    5.000000  403.000000   14.700000    2.960000
# 25%     87.900000    1.577250   24.000000  666.000000   20.200000   14.675000
# 50%     94.800000    1.914200   24.000000  666.000000   20.200000   18.130000
# 75%     99.000000    2.319700   24.000000  666.000000   20.200000   23.280000
# max    100.000000    3.545900   24.000000  666.000000   20.200000   37.970000
#
#              medv
# count  127.000000
# mean    16.159843
# std      8.631892
# min      5.000000
# 25%     10.950000
# 50%     14.100000
# 75%     19.100000
# max     50.000000

# %% [markdown]
# In areas with high crime rate, there are 0% of esidential land zoned for lots over 25,000 sq.ft.

# %% [markdown]
# #### (f) How many of the suburbs in this data set bound the Charles river?

# %%
boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# 35 suburbs in this data set bound the Charles River

# %% [markdown]
# #### (g) What is the median pupil-teacher ratio among the towns in this data set?

# %%
np.median(boston["ptratio"])
# Out:
# 19.05

# %% [markdown]
# #### (h) Which suburb of Boston has lowest median value of owneroccupied homes?
# #### What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
boston["medv"].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %%
boston['low_home_value'] = pd.cut(boston['medv'],[0,17.025,50],labels=['yes','no'])
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv high_crime_area low_home_value
# 0   4.98  24.0              no             no
# 1   9.14  21.6              no             no
# 2   4.03  34.7              no             no
# 3   2.94  33.4              no             no
# 4   5.33  36.2              no             no

# %%
low_home_value = boston[boston['low_home_value']=="yes"]
low_home_value.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000  127.000000
# mean    10.986203    0.393701   17.018189    0.039370    0.668157    5.886496
# std     14.208815    2.698934    4.641761    0.195244    0.094925    0.592155
# min      0.024980    0.000000    1.890000    0.000000    0.448000    4.138000
# 25%      1.513335    0.000000   18.100000    0.000000    0.603000    5.550500
# 50%      7.752230    0.000000   18.100000    0.000000    0.679000    5.950000
# 75%     13.795750    0.000000   18.100000    0.000000    0.713000    6.342000
# max     88.976200   25.000000   27.740000    1.000000    0.871000    7.313000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000  127.000000
# mean    92.868504    2.277718   17.141732  567.834646   19.651969   21.067795
# std      9.240411    1.173490    9.479907  153.257837    1.774996    5.972431
# min     37.800000    1.137000    1.000000  188.000000   14.700000    7.880000
# 25%     90.550000    1.598450    5.000000  403.000000   20.200000   17.115000
# 50%     95.400000    1.866200   24.000000  666.000000   20.200000   19.920000
# 75%     98.850000    2.334800   24.000000  666.000000   20.200000   24.275000
# max    100.000000    6.818500   24.000000  711.000000   21.200000   37.970000
#
#              medv
# count  127.000000
# mean    12.726772
# std      2.974533
# min      5.000000
# 25%     10.850000
# 50%     13.400000
# 75%     15.000000
# max     17.000000

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# std     28.148861    2.105710    8.707259  168.537116    2.164946    7.141062
# min      2.900000    1.129600    1.000000  187.000000   12.600000    1.730000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000    6.950000
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000   11.360000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000   16.955000
# max    100.000000   12.126500   24.000000  711.000000   22.000000   37.970000
#
#              medv
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# <pre>
# In areas with lowest median home value,
#     The mean crime rate is 3 times higher than the Boston area in general
# </pre>

# %% [markdown]
# #### (i) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling?
# #### Comment on the suburbs that average more than eight rooms per dwelling.

# %%
boston[boston["rm"] > 7]
# Out:
#          crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 2     0.02729   0.0   7.07     0  0.4690  7.185  61.1  4.9671    2  242
# 4     0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622    3  222
# 40    0.03359  75.0   2.95     0  0.4280  7.024  15.8  5.4011    3  252
# 55    0.01311  90.0   1.22     0  0.4030  7.249  21.9  8.6966    5  226
# 64    0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229    3  216
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 364   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016  97.5  1.2024   24  666
# 375  19.60910   0.0  18.10     0  0.6710  7.313  97.9  1.3163   24  666
# 453   8.24809   0.0  18.10     0  0.7130  7.393  99.3  2.4527   24  666
# 482   5.73116   0.0  18.10     0  0.5320  7.061  77.0  3.4106   24  666
#
#      ptratio  lstat  medv high_crime_area low_home_value
# 2       17.8   4.03  34.7              no             no
# 4       18.7   5.33  36.2              no             no
# 40      18.3   1.98  34.9              no             no
# 55      17.9   4.81  35.4              no             no
# 64      18.6   8.05  33.0              no             no
# ..       ...    ...   ...             ...            ...
# 364     20.2   5.29  21.9              no             no
# 370     20.2   2.96  50.0             yes             no
# 375     20.2  13.44  15.0             yes            yes
# 453     20.2  16.74  17.8             yes             no
# 482     20.2   7.01  25.0             yes             no
#
# [64 rows x 15 columns]

# %%
boston[boston["rm"] > 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# 364  3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
#
#      ptratio  lstat  medv high_crime_area low_home_value
# 97      18.0   4.21  38.7              no             no
# 163     14.7   3.32  50.0              no             no
# 204     14.7   2.88  50.0              no             no
# 224     17.4   4.14  44.8              no             no
# 225     17.4   4.63  50.0              no             no
# 226     17.4   3.13  37.6              no             no
# 232     17.4   2.47  41.7              no             no
# 233     17.4   3.95  48.3              no             no
# 253     19.1   3.54  42.8              no             no
# 257     13.0   5.12  50.0              no             no
# 262     13.0   5.91  48.8              no             no
# 267     13.0   7.44  50.0              no             no
# 364     20.2   5.29  21.9              no             no

# %%
boston[boston["rm"] > 8].shape
# Out:
# (13, 15)

# %% [markdown]
# ##### 64 suburbs averages more than 7 room per dwelling. 13 suburbs averages more than 8 room per dwelling.
# ##### None of the suburb with more than 8 room per dwelling can be classified as high crime area. None of the suburbs can be classified as low home value area.
